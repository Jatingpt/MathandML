# %% [markdown]
# <a href="https://colab.research.google.com/github/Jatingpt/MathandML/blob/main/MathandML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = {"name": ["Harry", "Pooja", "Vikas", "Rohit"],
        "Age": [23, 24, 24, 25],
        "Salary": [23000, 24000, 34000, 23000000]}

df = pd.DataFrame(data)
df
# Out:
#     name  Age    Salary
# 0  Harry   23     23000
# 1  Pooja   24     24000
# 2  Vikas   24     34000
# 3  Rohit   25  23000000

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe().T
# Out:
#         count       mean           std      min       25%      50%  \
# Age       4.0       24.0  8.164966e-01     23.0     23.75     24.0
# Salary    4.0  5770250.0  1.148650e+07  23000.0  23750.00  29000.0
#
#                75%         max
# Age          24.25        25.0
# Salary  5775500.00  23000000.0

# %%
sns.boxplot(x = "Salary", data = df)
plt.show()

# %%
#removing outliers by using IQR.
q1 = df["Salary"].quantile(0.25)
q3 = df["Salary"].quantile(0.75)
IQR =q3 - q1
IQR
# Out:
# 5751750.0

# %%
min_r = q1 - (1.5*(IQR))
max_r = q3 + (1.5*(IQR))
min_r, max_r
# Out:
# (-8603875.0, 14403125.0)

# %%
new_df = df[df["Salary"] <= max_r]
new_df
# Out:
#     name  Age  Salary
# 0  Harry   23   23000
# 1  Pooja   24   24000
# 2  Vikas   24   34000

# %%
new_df.shape
# Out:
# (3, 3)

# %%
sns.boxplot(x = "Salary", data = new_df)
plt.show()
